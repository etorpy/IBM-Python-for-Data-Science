# %% [markdown]
# <h3> Get to Know a numpy Array </h3>

# %% [markdown]
# cast the following list to a numpy array:

# %%
import numpy as np
a=[1,2,3,4,5]
u=np.array(a)    # added these 2 lines
u
# Out:
# array([1, 2, 3, 4, 5])

# %% [markdown]
# 1) type using the function type

# %%
type(u)
# Out:
# numpy.ndarray

# %% [markdown]
# 2) the shape of the array

# %%
u.shape
# Out:
# (5,)

# %% [markdown]
# 3) the type of data in the array

# %%
u.dtype
# Out:
# dtype('int64')

# %% [markdown]
# 4) find the mean of the array

# %%
u.mean()
# Out:
# 3.0

# %% [markdown]
# <h3> Creating and Plotting Functions  </h3>

# %% [markdown]
# 1) create the following functions using the numpy array <code> x </code>

# %% [markdown]
# $$y=sin(x)+2$$

# %%
x=np.linspace(0,2*np.pi,100)
𝑦=np.𝑠𝑖𝑛(𝑥)+2    # NOTE: need to reference the numpy library to use the sin function

# %% [markdown]
# 2)  plot the function

# %%
import matplotlib.pyplot as plt
# %matplotlib inline  
plt.plot(x,y)    # added this line

# %% [markdown]
# <hr>
# <small>Copyright &copy; 2018 IBM Cognitive Class. This notebook and its source code are released under the terms of the [MIT License](https://cognitiveclass.ai/mit-license/).</small>
